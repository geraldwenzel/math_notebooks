# %%
# %run ../set_notebook.py

# %%
plt.plot([2, 0],[1, -1/3])
plt.grid()
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.axhline(0, color='black', lw=2)
_=plt.axvline(0, color='black', lw=2)

# %%
x_coords = np.linspace(-10, 10, 1000)
y_coords = [3*x_coord-2 for x_coord in x_coords]
y_coords2 = [3*x_coord+6 for x_coord in x_coords]

plt.plot(x_coords, y_coords)
plt.plot(x_coords, y_coords2)

plt.grid()
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.axhline(0, color='black', lw=2)
_=plt.axvline(0, color='black', lw=2)
